# %%
import pandas as pd
filename = pd.read_csv('food_balance_sheet.csv', encoding = 'latin-1')
lst = [['35', 'Portugal', 94],
           ['33', 'Argentina', 30],
           ['30', 'Brazil', 92]]
col = ['Age','Nationality','Overall']
df = pd.DataFrame(lst, columns = col, index = [1, 2, 3])
print(df)
# Out:
#   Age Nationality  Overall
# 1  35    Portugal       94
# 2  33   Argentina       30
# 3  30      Brazil       92

# %%
import pandas as pd 
filename = pd.read_csv('food_balance_sheet.csv', encoding ='latin-1')

filename.groupby('Area')['Y2017'].sum()
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Comoros                             59.84
# Congo                            41181.68
# Côte d'Ivoire                   224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# Guinea-Bissau                    19102.77
# ...

# %%
import pandas as pd
filename = pd.read_csv('food_balance_sheet.csv', encoding ='latin-1')

filename.groupby('Area').count()
# Out:
#                              Area Code  Item Code  Item  Element Code  \
# Area
# Algeria                           1313       1313  1313          1313
# Angola                            1424       1424  1424          1424
# Benin                             1285       1285  1285          1285
# Botswana                          1378       1378  1378          1378
# Burkina Faso                      1409       1409  1409          1409
# Cabo Verde                        1260       1260  1260          1260
# Cameroon                          1460       1460  1460          1460
# Central African Republic          1344       1344  1344          1344
# Chad                              1343       1343  1343          1343
# Comoros                             45         45    45            45
# Congo                             1413       1413  1413          1413
# Côte d'Ivoire                     1467       1467  1467          1467
# ...

# %%
import numpy as np
a = np.array([[94,89,63],
             [93,92,48],
             [92,94,56]])

print(a[:2,1:])
# Out:
# [[89 63]
#  [92 48]]

# %%
import numpy as np
S = np.array([['him','sell'],
              [90,28,43]])

print(S[0][1][1])
# Out:
# e
# C:\Users\kushi\AppData\Local\Temp\ipykernel_14788\1065795155.py:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   S = np.array([['him','sell'],

# %%
import pandas as pd
filename = pd.read_csv('food_balance_sheet.csv', encoding = 'latin-1')
filename['Y2014'].isnull().sum()
# Out:
# 1589

# %%
import pandas as pd
filename = pd.read_csv('food_balance_sheet.csv', encoding = 'latin-1')
filename['Y2014'].isnull().sum()/len(filename['Y2014'])
# Out:
# 0.026073544131401474

# %%
import pandas as pd
filename = pd.read_csv('food_balance_sheet.csv', encoding = 'latin-1')
filename.groupby('Element')['Y2014','Y2015','Y2016','Y2017','Y2018'].sum()
# Out:
# C:\Users\kushi\AppData\Local\Temp\ipykernel_14788\29782587.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   filename.groupby('Element')['Y2014','Y2015','Y2016','Y2017','Y2018'].sum()
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# ...

# %%
import pandas as pd
filename = pd.read_csv('food_balance_sheet.csv', encoding ='latin-1')

filename['Y2017'].mean()
# Out:
# 140.917764860268

# %%
import pandas as pd
filename = pd.read_csv('food_balance_sheet.csv', encoding ='latin-1')

filename['Y2017'].std()
# Out:
# 1671.8623590572788

# %%
import pandas as pd
filename = pd.read_csv('food_balance_sheet.csv', encoding ='latin-1')
filename.groupby('Area')['Y2017'].sum()
# Out:
# Area
# Algeria                         325644.27
# Angola                          229159.57
# Benin                           124771.22
# Botswana                         22101.30
# Burkina Faso                    101855.07
# Cabo Verde                       14650.74
# Cameroon                        232030.43
# Central African Republic         29937.00
# Chad                             71594.68
# Comoros                             59.84
# Congo                            41181.68
# Côte d'Ivoire                   224599.01
# Djibouti                         22729.91
# Egypt                           866379.92
# Eswatini                         54343.33
# Ethiopia                        448683.76
# Ethiopia PDR                         0.00
# Gabon                            27979.64
# Gambia                           23154.18
# Ghana                           337599.06
# Guinea                           98138.87
# Guinea-Bissau                    19102.77
# ...

# %%
import pandas as pd
filename = pd.read_csv('food_balance_sheet.csv', encoding ='latin-1')
filename.groupby('Element')['Y2017'].sum()
# Out:
# Element
# Domestic supply quantity                  2088198.10
# Export Quantity                            182338.80
# Fat supply quantity (g/capita/day)          10253.84
# Feed                                       223705.68
# Food                                      1258888.28
# Food supply (kcal/capita/day)              454681.00
# Food supply quantity (kg/capita/yr)         48690.04
# Import Quantity                            294559.09
# Losses                                     160614.00
# Other uses (non-food)                       91645.97
# Processing                                 292836.00
# Production                                2030056.89
# Protein supply quantity (g/capita/day)      11842.45
# Residuals                                   35500.00
# Seed                                        24870.14
# Stock Variation                             54316.91
# Total Population - Both sexes             1112641.00
# Tourist consumption                            91.00
# ...

# %%
import numpy as np 
my_tuppy = (1,2,5,8)
my_tuppy[2]=6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14788\1545503252.py in <module>
#       1 import numpy as np
#       2 my_tuppy = (1,2,5,8)
# ----> 3 my_tuppy[2]=6
#
# TypeError: 'tuple' object does not support item assignment

# %%
import pandas as pd
filename = pd.read_csv('food_balance_sheet.csv', encoding ='latin-1')
filename.groupby('Item')['Y2015','Y2018'].sum()
# Out:
# C:\Users\kushi\AppData\Local\Temp\ipykernel_14788\3091465324.py:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   filename.groupby('Item')['Y2015','Y2018'].sum()
#                          Y2015      Y2018
# Item
# Alcohol, Non-Food      2180.00    2293.00
# Alcoholic Beverages   98783.72   97847.27
# Animal Products       11811.73   11578.61
# Animal fats          200675.72  269648.27
# Apples and products   10559.15    9640.51
# ...                        ...        ...
# Vegetables, Other    158104.08  163987.21
# Vegetal Products     107064.17  107775.39
# Wheat and products   234710.51  242645.19
# Wine                   4251.81    4039.32
# Yams                 203151.78  221272.09
#
# [119 rows x 2 columns]

# %%
import numpy as np 
y = [(2, 4), (7, 8), (1, 5, 9)]

y[1][1]
# Out:
# 8
